# %% [markdown]
# <a href="https://www.kaggle.com/code/taimour/hugging-face-tensorflow-xla?scriptVersionId=211725228" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import tensorflow as tf
from transformers import AutoTokenizer, TFAutoModelForCausalLM

# Load a pre-trained tokenizer and model (e.g., gpt2)
tokenizer = AutoTokenizer.from_pretrained("gpt2")
model = TFAutoModelForCausalLM.from_pretrained("gpt2")

# Define the input text and topic
input_text = "Work hard"

# Encode the input text
input_ids = tokenizer.encode(input_text, return_tensors="tf")

# Define the text generation function
@tf.function
def generate_text(input_ids):
  with tf.xla.experimental.jit_scope():
    output = model.generate(
        input_ids=input_ids,
        max_length=100,
        num_return_sequences=1,
        do_sample=True,
        top_k=50,
        top_p=0.95,
    )
  return output

# Generate text using the XLA-compiled function
output = generate_text(input_ids)

# Decode the generated text
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(generated_text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2LMHeadModel.
#
# All the weights of TFGPT2LMHeadModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# WARNING: AutoGraph could not transform <bound method Socket.send of <zmq.Socket(zmq.PUSH) at 0x7fa73ce9e860>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733579350.713736      57 service.cc:145] XLA service 0x7fa678005a20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733579350.713828      57 service.cc:153]   StreamExecutor device (0): Host, Default Version
# I0000 00:00:1733579350.891091      56 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Work hard work and be the best you can. You must learn to love and be part of your team. Don't let others give you shit. It's not about getting more bang for your buck, it's about not being afraid of your job. Don't take yourself too seriously, don't overthink your choices. Don't be afraid to be yourself, never stop trying.
#
# The bottom line is that you will never be someone the world over when you are working hard, but you
